# %% [markdown]
# # Correlation Data Analysis

# %% [markdown]
# ### Import Data and Libraries

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()

# %% [markdown]
# ### Supporting Functions

# %% [markdown]
# #### Energy Consumption Column

# %%
# Return a Dataframe of building energy consumption totals from Jan 1, Aug 30
def get_bldg_totals():
    df_data = pd.read_csv('../data/year_data/2018-01-01_2018-08-30.csv')
    bldg_totals = df_data.sum()[1:]
    bldg_totals = bldg_totals.divide(4)
    return pd.DataFrame(bldg_totals)

# df - Dataframe to update
# bldg_totals - Dataframe of Buildings and their energy consumption
# If a building in the dataframe is found in the building list then its energy consumption total will be updated
def update_energy_cons(df, bldg_totals):
    matches = []
    for i in range(df_corr.shape[0]):
        curr_bldg = remove_zero(df_corr['Facility'][i])
        for j in range(bldg_totals.shape[0]):
            if curr_bldg == remove_zero(bldg_totals.iloc[j].name[1:]):
                df_corr['Energy Cons'][i] = bldg_totals.iloc[j][0]
                matches.append(curr_bldg)
    print("Number of Matched and Updated Buildings: " + str(len(matches)))
    
# df - dataframe
# Adds Energy Column with the appropriate total. Removes rows that do not have an energy total
def add_energy_cons_col(df): 
    # Create Energy Consumption Row - Initialize with 0's (Will be Updated)
    df['Energy Cons'] = df['Constr Cost'].apply(lambda x: 0)
    # Get Bldg Total Energy Usage (Dataframe) from Jan - Aug 2018
    bldg_totals = get_bldg_totals()
    # If a building in the dataframe is found in the building list then its energy consumption total will be updated
    update_energy_cons(df, bldg_totals)
    return df

# %% [markdown]
# #### Utitlity Functions

# %%
# Remove the Leading 0's in a String
def remove_zero(string):
    if string[0] != '0': return string
    return remove_zero(string[1:])

# %% [markdown]
# #### Dataframe Manipulation

# %%
# df - Dataframe that contains a 'RI-Aux-Other' Column
# Split the Research/Aux/Other Column
def split_RAO(df):
    df['RI'] = df['RI-Aux-Other'].apply(lambda x: int(x.split('-')[0]))
    df['Aux'] = df['RI-Aux-Other'].apply(lambda x: int(x.split('-')[1]))
    df['Other'] = df['RI-Aux-Other'].apply(lambda x: int(x.split('-')[2]))
    df = df.drop(['RI-Aux-Other'], axis=1)
    return df
    
# col_list - List of Column Labels to Convert to String
# df - dataframe
# Convert Categorical Columns Into Strings
def convert_col_to_string(df, col_list):
    for i in col_list: df[i] = df[i].apply(lambda x: str(x))
    return df

# %% [markdown]
# #### Plotting

# %%
# df - Dataframe of Correlations
# Plots Seaborn Heatmap of Correlation. Hides Redundant Squares
def plot_corr_heatmap(df):
    mask = np.zeros_like(df_corr)
    mask[np.triu_indices_from(mask)] = True
    with sns.axes_style("white"):
         ax = sns.heatmap(df_corr, mask=mask, square=False, linewidths=.5, vmin=-1, vmax=1, cmap="Reds")
            
# df_corr - Dataframe with Correlations
# df_orig - Dataframe with Original Data
# x_label - The X-Label for all Scatter Plots
# Plots a scatter plot of the all of the columns in df_corr in respect to each other
def plot_corr_scatter(df_corr, df_orig, x_label):
    correlation_col = df_corr.corr().columns.values
    for i in correlation_col:
        if i != x_label:
            plt.scatter(x=df_corr_orig[x_label].values,
                        y=df_corr_orig[i].values)
            plt.title('Scatter Plot of Energy Consumption and ' + i)
            plt.xlabel(x_label)
            plt.ylabel(i)
            plt.show()
            
# df - Dataframe with Correlations
# df_orig - Dataframe with Original Data
# x_label - The X-Label for all Scatter Plots
# Plots a scatter plot of the all of the columns in df_corr in respect to each other
def plot_corr_scatter_sns(df_corr, df_orig, x_label, hue, fit_reg=False):
    correlation_col = df_corr.corr().columns.values
    for i in correlation_col:
        if i != x_label:
            ax = sns.lmplot(x=x_label, y=i, data=df_orig, hue=hue, fit_reg=fit_reg)
            plt.title('Scatter Plot of ' + x_label + ' and ' + i)
            plt.show()

# %% [markdown]
# ### Original Building Metadata Dataframe

# %%
# Importing the Complete Building Metadata dataset
df_bldg = pd.read_csv('../data/bldg_info.csv')

# %%
df_bldg.columns.values
# Out:
# array(['Site', 'Facility', 'Name', 'Type', 'Category', 'Area', 'Status',
#        'Ownership', 'Primary Use', 'Condition', 'Named For',
#        'Constr Date', 'Occup Date', 'Architect', 'Contractor',
#        'Constr Cost', 'GT Category', 'FIR Cong Dist', 'On Campus (IRP)',
#        'FIR Constr Type', 'FIR Name', 'FIR Proj No', 'Address',
#        'RI-Aux-Other', 'ASF', 'NonASF', 'FIR Pct Renov', 'Avg cost/sf',
#        'FIR year renov', 'Demo', 'Cty/dorm/apt/hse', 'Remarks'],
#       dtype=object)

# %%
df_bldg
# Out:
#        Site Facility                                               Name  \
# 0    MainGT      002          Skiles, William Vernon Classroom Building
# 1    MainGT      003                          Robert, L.W. Alumni House
# 2    MainGT      006                      Smith, John M. Residence Hall
# 3    MainGT      007                       Brown, Julius Residence Hall
# 4    MainGT      010                       Howell, Clark Residence Hall
# 5    MainGT      011                Harris, Nathanial E. Residence Hall
# 6    MainGT      012                    Brittain, Marion L. Dining Hall
# 7    MainGT      013                    Cloudman, Josiah Residence Hall
# 8    MainGT      014             Harrison, George W. Jr. Residence Hall
# 9    MainGT      015                  Towers, Donigan D. Residence Hall
# 10   MainGT      016                   Glenn, William H. Residence Hall
# 11   MainGT     016A                                       GT Connector
# 12   MainGT      017                 Dodd, Bobby Stadium at Grant Field
# 13   MainGT      018    Edge, Arthur B. Intercollegiate Athletic Center
# 14   MainGT     018A          Rice, Homer Center for Sports Performance
# 15   MainGT      020                         WREK Transmitter and Tower
# 16   MainGT      022                            Daniel, J.L. Laboratory
# 17   MainGT     022A                                Daniel Lab Addition
# 18   MainGT     023A                                    OIT Engineering
# 19   MainGT      024                                    Smith, David M.
# 20   MainGT      025                                   Chapin, Lloyd W.
# 21   MainGT      026        Holland, Archibald D. (Heating and Cooling)
# 22   MainGT     029A                                        Hall, Lyman
# 23   MainGT     029B                             Emerson, William Henry
# 24   MainGT     029C                             Lyman/Emerson Addition
# 25   MainGT      030                                      French, Aaron
# 26   MainGT      031                 Moore, Bill Student Success Center
# 27   MainGT      032                      ACC Network Production Center
# 28   MainGT      033                                 O'Keefe, Daniel C.
# 29   MainGT     033A                                        O'Keefe Gym
# ..      ...      ...                                                ...
# 145  MainGT      172                                College of Business
# 146  MainGT      173                                  760 Spring Street
# 147  MainGT      175                         Technology Square Research
# 148  MainGT      176                                       Centergy One
# 149  MainGT      177         Whitehead, Joseph B. Student Health Center
# 150  MainGT      178                          828 West Peachtree Street
# 151  MainGT      179                          830 West Peachtree Street
# 152  MainGT      180                                  Family Apartments
# 153  MainGT      181                              Marcus Nanotechnology
# 154  MainGT      184                           831 Marietta Street N.W.
# 155  MainGT      185                            Strong Street Gatehouse
# 156  MainGT      186                           755 Marietta Street N.W.
# 157  MainGT      187                           793 Marietta Street N.W.
# 158  MainGT      189                           Substation Control House
# 159  MainGT      191                            North Avenue Apartments
# 160  MainGT      195  Roger A. and Helen B. Krone Engineered Biosystems
# 161  MainGT      196         Mewborn, Shirley Clements Softball Stadium
# 162  MainGT      198                                Academy of Medicine
# 163  MainGT      199         Carbon-Neutral Energy Solutions Laboratory
# 164  MainGT      200  Brock, Mary R. & John F. Football Practice Fac...
# 165  MainGT      201                          Challenge Course Pavilion
# 166  MainGT      203                          Byers, Ken Tennis Complex
# 167  MainGT      209                        West Village Dining Commons
# 168  MainGT      212                               CRC Storage Building
# 169  MainGT      709                                  162 Fourth Street
# 170  MainGT      720                           Heffernan, Paul H. House
# 171  MainGT      785                      Technology Enterprise Park #1
# 172  MainGT      791                    Landon, R. Kirk Learning Center
# 173  MainGT      850              575 Fourteenth Street Engineering Ctr
# 174  MainGT      876                                           Biltmore
#
#          Type Category    Area Status  Ownership  Primary Use Condition  \
# 0    BUILDING        M  139914      A          1            2  REM26-50
# 1    BUILDING        M   25645      A          1            1     SATIS
# 2    BUILDING        M   63848      A          1           23     SATIS
# 3    BUILDING        M   17423      A          1           22     SATIS
# 4    BUILDING        M   23933      A          1           22     SATIS
# 5    BUILDING        M   25558      A          1           22     SATIS
# 6    BUILDING        M   19986      A          1            8     SATIS
# 7    BUILDING        M   23117      A          1           22     SATIS
# 8    BUILDING        M   30526      A          1           22     SATIS
# 9    BUILDING        M   59986      A          1           23     SATIS
# 10   BUILDING        M   70496      A          1           23     SATIS
# 11   BUILDING        M    8591      A          1            1     SATIS
# 12   BUILDING        M  347094      A          2           10     SATIS
# 13   BUILDING        M   72775      A          2            1     SATIS
# 14   BUILDING        M   39749      A          2            1     SATIS
# 15   BUILDING        M     384      A          1            1     SATIS
# 16   BUILDING        M   22294      A          1            4     SATIS
# 17   BUILDING        M    4152      A          1            4     SATIS
# 18   BUILDING        M    2375      A          1            1     SATIS
# 19   BUILDING        M   38306      A          1            2  REM26-50
# 20   BUILDING        M   10310      A          1            1     SATIS
# 21   BUILDING        M   34372      A          1            6    REM>51
# 22   BUILDING        M   18445      A          1            1     SATIS
# 23   BUILDING        M   16366      A          1            1     SATIS
# 24   BUILDING        M    7720      A          1            1     SATIS
# 25   BUILDING        M   33107      A          1            1     SATIS
# 26   BUILDING        M   48666      A          1            1     SATIS
# 27   BUILDING        M    7591      A          1            1     SATIS
# 28   BUILDING        M  111907      A          1            1    REM<26
# 29   BUILDING        M   34953      A          1            9  REM26-50
# ..        ...      ...     ...    ...        ...          ...       ...
# 145  BUILDING        M  264432      A          2            2     SATIS
# 146  BUILDING        M   67423      A          2            1     SATIS
# 147  BUILDING        M  215248      A          4            4     SATIS
# 148  BUILDING        M  148391      A          5            4     SATIS
# 149  BUILDING        M   38750      A          1            5     SATIS
# 150  BUILDING        M   49663      A          1            1     SATIS
# 151  BUILDING        M   49553      A          1            1     SATIS
# 152  BUILDING        M  394386      A          2           24     SATIS
# 153  BUILDING        M  194852      A          9            4     SATIS
# 154  BUILDING        M   23300      A          1            4     SATIS
# 155  BUILDING        M     291      A          1            1     SATIS
# 156  BUILDING        M   12420      A          1            1     SATIS
# 157  BUILDING        M   18917      A          1            1     SATIS
# 158  BUILDING        M     624      A          2           16     SATIS
# 159  BUILDING        M  966203      A          2           23     SATIS
# 160  BUILDING        M  224925      A          1            4     SATIS
# 161  BUILDING        M    7094      A          1           10     SATIS
# 162  BUILDING        M   20030      A          2            1     SATIS
# 163  BUILDING        M   46888      A          2            4     SATIS
# 164  BUILDING        M   82144      A          1            9     SATIS
# 165  BUILDING        M    3885      A          1            9     SATIS
# 166  BUILDING        M   50935      A          1            9     SATIS
# 167  BUILDING        M   60120      A          1            8     SATIS
# 168  BUILDING        M    2304      A          1            9     SATIS
# 169  BUILDING        M    3800      A          1           20     SATIS
# 170  BUILDING        M    4375      A          1            1     SATIS
# 171  BUILDING        M   32705      A          5            4     SATIS
# 172  BUILDING        N   11743      A          6            1     SATIS
# 173  BUILDING        N  117159      A          5            4     SATIS
# 174  BUILDING        N   20673      A          4            1     SATIS
#
#                            ...                                   Address  \
# 0                          ...                             686 Cherry St
# 1                          ...                          190 North Avenue
# 2                          ...                           630 Williams St
# 3                          ...                           625 Techwood Dr
# 4                          ...                           640 Williams St
# 5                          ...                           633 Techwood Dr
# 6                          ...                           649 Techwood Dr
# 7                          ...                           661 Techwood Dr
# 8                          ...                           660 Williams St
# 9                          ...                          112 Bobby Dodd W
# 10                         ...                          118 Bobby Dodd W
# 11                         ...                          116 Bobby Dodd W
# 12                         ...                          155 North Avenue
# 13                         ...                          150 Bobby Dodd W
# 14                         ...                          154 Bobby Dodd W
# 15                         ...                             850 Curran St
# 16                         ...                          200 Bobby Dodd W
# 17                         ...                          200 Bobby Dodd W
# 18                         ...                          220 Bobby Dodd W
# 19                         ...                             685 Cherry St
# 20                         ...                             681 Cherry St
# 21                         ...                           680 Power Plant
# 22                         ...                          221 Uncle Heinie
# 23                         ...                          221 Uncle Heinie
# 24                         ...                          221 Uncle Heinie
# 25                         ...                          237 Uncle Heinie
# 26                         ...                          219 Uncle Heinie
# 27                         ...                             955 Fowler St
# 28                         ...                          151 Sixth Street
# 29                         ...                          151 Sixth Street
# ..                         ...                                       ...
# 145                        ...                           800 W Peachtree
# 146                        ...                             760 Spring St
# 147                        ...                               85 Fifth St
# 148                        ...                               75 Fifth St
# 149                        ...                              740 Ferst Dr
# 150                        ...                               828 W Ptree
# 151                        ...                               830 W Ptree
# 152                        ...                              251 Tenth St
# 153                        ...                           345 Ferst Dr NW
# 154                        ...                           831 Marietta St
# 155                        ...                             637 Strong St
# 156                        ...                           755 Marietta St
# 157                        ...                           793 Marietta St
# 158                        ...                          665 Northside Dr
# 159                        ...                             120 North Ave
# 160                        ...                           950 Atlantic Dr
# 161                        ...                             935 Fowler St
# 162                        ...                               875 W Ptree
# 163                        ...                           495 Tech Way NW
# 164                        ...                             237 Cherry St
# 165                        ...                              816 Ferst Dr
# 166                        ...                             960 Fowler St
# 167                        ...                            532 Eighth St.
# 168                        ...                             750 Ferst Dr.
# 169                        ...                             162 Fourth St
# 170                        ...                          166 Fifth Street
# 171                        ...                          387 Technology C
# 172                        ...                            1015 Tumlin St
# 173                        ...                           575 14th Street
# 174                        ...                           817 W Peachtree
#
#     RI-Aux-Other       ASF  NonASF FIR Pct Renov  Avg cost/sf  FIR year renov  \
# 0    100-000-000   71356.0   55115          43.0          175   1/1/1995 0:00
# 1    050-000-050   15982.0    4698         100.0          160   1/1/1979 0:00
# 2    001-099-000   40141.0   15015          60.0          160   1/1/1993 0:00
# 3    001-099-000   10985.0    3267          60.0          130   1/1/1993 0:00
# 4    001-099-000   14697.0    6012          80.0          130   1/1/1999 0:00
# 5    001-099-000   13240.0    8230         100.0          130   1/1/1992 0:00
# 6    000-100-000   14280.0    2415          60.0          160   1/1/2001 0:00
# 7    001-099-000   13832.0    5204          60.0          130   1/1/1995 0:00
# 8    001-099-000   19616.0    6095          80.0          130   1/1/1998 0:00
# 9    001-099-000   29971.0   21864         100.0          130   1/1/2014 0:00
# 10   001-099-000   39124.0   21552         100.0          130   8/1/2015 0:00
# 11   000-100-000    4391.0    2909           NaN          130             NaN
# 12   012-000-088  125124.0  189166          80.0          190   1/1/2003 0:00
# 13   000-000-100   45340.0   20013           0.0          140             NaN
# 14   000-000-100   28046.0    7112           0.0          160             NaN
# 15   100-000-000     328.0       0           0.0          130             NaN
# 16   100-000-000   11807.0    7383         100.0          250   1/1/1994 0:00
# 17   100-000-000    2402.0    1164           0.0          250             NaN
# 18   100-000-000    1975.0      88           0.0          140             NaN
# 19   100-000-000   23027.0   11218           0.0          190             NaN
# 20   100-000-000    4102.0    3992         100.0          160  12/1/2014 0:00
# 21   100-000-000    1251.0   28613         100.0          550   1/1/1973 0:00
# 22   100-000-000   13545.0    2111         100.0          160   1/1/1991 0:00
# 23   100-000-000   10080.0    3482         100.0          160   1/1/1991 0:00
# 24   100-000-000     795.0    6363           0.0          160             NaN
# 25   100-000-000   20318.0    8546         100.0          160   1/1/1985 0:00
# 26   100-000-000   26362.0   17593           0.0          160             NaN
# 27   000-000-100    5445.0    1366         100.0          140   1/1/2019 0:00
# 28   100-000-000   66431.0   32872           0.0          120             NaN
# 29   032-000-068   27045.0    5609           0.0          140             NaN
# ..           ...       ...     ...           ...          ...             ...
# 145  075-025-000  165002.0   75079           NaN          190             NaN
# 146  075-000-025   37448.0   22586           NaN          160             NaN
# 147  100-000-000  147851.0   50373           NaN          250             NaN
# 148  062-000-038  122572.0    1236           NaN          250             NaN
# 149  000-100-000   27547.0    7574           NaN          250             NaN
# 150  072-028-000   35725.0    9355          30.0          140   1/1/2010 0:00
# 151  000-000-100   49553.0       0           NaN          140             NaN
# 152  001-099-000  254375.0   76525           NaN          160             NaN
# 153  100-000-000  102880.0   79714           NaN          250             NaN
# 154  080-000-020   16408.0    4599          75.0          180   1/1/2008 0:00
# 155  000-100-000     172.0      55           NaN          120             NaN
# 156  100-000-000   10400.0     873         100.0          120   1/1/2017 0:00
# 157  100-000-000   14545.0    1969           NaN          120             NaN
# 158  100-000-000       NaN     583           NaN           45             NaN
# 159  001-099-000  591261.0  264847           NaN          160             NaN
# 160  100-000-000  122145.0   81526           NaN          250             NaN
# 161  000-000-100    4599.0    1698           NaN          220             NaN
# 162  100-000-000   14061.0    3258          50.0          140   1/1/2012 0:00
# 163  050-000-050   22926.0   20501           NaN          250             NaN
# 164  000-000-100   79149.0     531           NaN          140             NaN
# 165  000-000-100     216.0    3503           NaN          140             NaN
# 166  000-000-100   44076.0    3661           NaN          140             NaN
# 167  050-050-000   34902.0   20753           NaN          160             NaN
# 168  100-000-000    2054.0       0           NaN          110             NaN
# 169  000-100-000    3800.0       0           0.0           50             NaN
# 170  100-000-000    2907.0     763           0.0          140             NaN
# 171  100-000-000   24719.0    4913           NaN          250             NaN
# 172  000-000-100    9239.0    1407           0.0          120             NaN
# 173  066-022-012   89166.0   19962         100.0          180   1/1/1990 0:00
# 174  100-000-000   16713.0    1698           NaN          140             NaN
#
#      Demo                                   Cty/dorm/apt/hse  \
# 0     NaN                                     060/ - / - / -
# 1     NaN                                     060/ - / - / -
# 2     NaN                         060/0283-0283/0001-0001/ -
# 3     NaN                         060/0089-0089/0001-0001/ -
# 4     NaN                               060/0122-0122/ - / -
# 5     NaN                         060/0092-0092/0000-0000/ -
# 6     NaN                                     060/ - / - / -
# 7     NaN                         060/0117-0117/0001-0001/ -
# 8     NaN                         060/0151-0151/0001-0001/ -
# 9     NaN                         060/0254-0254/0001-0001/ -
# 10    NaN                         060/0332-0332/0001-0001/ -
# 11    NaN                         060/0000-0000/0000-0000/ -
# 12    NaN                                     060/ - / - / -
# 13    NaN                                     060/ - / - / -
# 14    NaN                  060/0000-0000/0000-0000/0000-0000
# 15    NaN                  060/0000-0000/0000-0000/0000-0000
# 16    NaN                  060/0000-0000/0000-0000/0000-0000
# 17    NaN                  060/0000-0000/0000-0000/0000-0000
# 18    NaN                                     060/ - / - / -
# 19    NaN                                     060/ - / - / -
# 20    NaN                                     060/ - / - / -
# 21    NaN                                     060/ - / - / -
# 22    NaN                  060/0000-0000/0000-0000/0000-0000
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 145                                                NaN
# 146      Legal Dept move in 6/2010 No change in RI CAA
# 147                                                NaN
# 148  RI update 2013 RI Update 5/28/15 sf per curren...
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152  1% RI - AVPFAC request 3/2011, Steam/chill wat...
# 153                                                NaN
# 154  Partially leased beginning in 1995; acquired 5...
# 155                                                NaN
# 156                                                NaN
# 157                                                NaN
# 158                  Amy Landsberg - Power wrap Design
# 159  24.7 m GTFI upgrades and renovation. 1% RI - A...
# 160                                                NaN
# 161                                                NaN
# 162  Renovation 2012: R. Kennon Perry, Architects R...
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167  Complete project ID is BR-30-1407. FIDC only a...
# 168                                                NaN
# 169                                                NaN
# 170  $1/year lease from GT Foundation beginning in ...
# 171                                Lease sf is 33,997.
# 172                                                NaN
# 173                                                NaN
# 174          Lease amendment + New Leased space 6/2014
#
# [175 rows x 32 columns]

# %% [markdown]
# ### Prepare Correlation Matrix Dataframe

# %%
# Importing the dataset
df_corr = pd.read_csv('../data/bldg_info_corr.csv')

# Split the Research/Aux/Other Column and Remove Irrelevant Columns
df_corr = split_RAO(df_corr)
df_corr = df_corr.drop(['Constr Date', 'Occup Date', 'FIR year renov', 'Renov Date Num', 'FIR Pct Renov', 'Occup Date Num'], axis=1)

# Convert Categorical Columns Into Strings
df_corr = convert_col_to_string(df_corr, ['Ownership', 'Primary Use','FIR Constr Type'])

# Drop Stadium Row
df_corr = df_corr.drop(df_corr.loc[df_corr['Facility'] == '17'].index[0])
df_corr = df_corr.reset_index().drop(['index'], axis=1)

# Numerical Label Conditions
#cond_dict = {'REM>51': 1, 'REM26-50': 2, 'REM<26': 3, 'SATIS': 4}
#for i in range(df_corr.shape[0]): df_corr.at[i, 'Condition'] = cond_dict.get(df_corr['Condition'][i])

# %%
df_corr
# Out:
#     Facility    Area Ownership Primary Use Condition  Constr Date Num  \
# 0          2  139914         1           2  REM26-50            21551
# 1          3   25645         1           1     SATIS             4019
# 2          6   63848         1          23     SATIS            17168
# 3          7   17423         1          22     SATIS             9133
# 4         10   23933         1          22     SATIS            14246
# 5         11   25558         1          22     SATIS             9498
# 6         12   19986         1           8     SATIS            10228
# 7         13   23117         1          22     SATIS            11324
# 8         14   30526         1          22     SATIS            14246
# 9         15   59986         1          23     SATIS            17168
# 10        16   70496         1          23     SATIS            17168
# 11      016A    8591         1           1     SATIS            42005
# 12        18   72775         2           1     SATIS            29952
# 13      018A   39749         2           1     SATIS            35065
# 14        20     384         1           1     SATIS            31048
# 15        22   22294         1           4     SATIS            15342
# 16      022A    4152         1           4     SATIS            34335
# 17      023A    2375         1           1     SATIS             9863
# 18        24   38306         1           2  REM26-50             8402
# 19        25   10310         1           1     SATIS             3654
# 20        26   34372         1           6    REM>51             5115
# 21      029A   18445         1           1     SATIS             2193
# 22      029B   16366         1           1     SATIS             9133
# 23      029C    7720         1           1     SATIS            33239
# 24        30   33107         1           1     SATIS                1
# 25        31   48666         1           1     SATIS            33604
# 26        32    7591         1           1     SATIS            32143
# 27        33  111907         1           1    REM<26             8767
# 28      033A   34953         1           9  REM26-50             8767
# 29      033B    6478         1           1     SATIS             8767
# ..       ...     ...       ...         ...       ...              ...
# 144      172  264432         2           2     SATIS            36892
# 145      173   67423         2           1     SATIS            36892
# 146      175  215248         4           4     SATIS            36892
# 147      176  148391         5           4     SATIS            37622
# 148      177   38750         1           5     SATIS            37257
# 149      178   49663         1           1     SATIS            17533
# 150      179   49553         1           1     SATIS            38718
# 151      180  394386         2          24     SATIS            37987
# 152      181  194852         9           4     SATIS            39448
# 153      184   23300         1           4     SATIS            31778
# 154      185     291         1           1     SATIS            38718
# 155      186   12420         1           1     SATIS            28856
# 156      187   18917         1           1     SATIS            31048
# 157      189     624         2          16     SATIS            38718
# 158      191  898703         2          23     SATIS            34700
# 159      195  224925         1           4     SATIS            42005
# 160      196    7094         1          10     SATIS            39448
# 161      198   20030         2           1     SATIS            14977
# 162      199   46888         2           4     SATIS            40909
# 163      200   82144         1           9     SATIS            40544
# 164      201    3885         1           9     SATIS            40544
# 165      203   50935         1           9     SATIS            41275
# 166      209   60120         1           8     SATIS            42736
# 167      212    2304         1           9     SATIS            42736
# 168      709    3800         1          20     SATIS            10959
# 169      720    4375         1           1     SATIS             9863
# 170      785   32705         5           4     SATIS            39083
# 171      791   11743         6           1     SATIS            37622
# 172      850  117159         5           4     SATIS            18264
# 173      876   20673         4           1     SATIS            40909
#
#      Constr Date Replaced  Constr Replaced pct  Constr Cost GT Category  \
# 0                   34700             27205.07      2037000     ACADI&R
# 1                   28856             28856.00      1142000    CAMPSUPP
# 2                   33970             27249.20       614000    RESIDENT
# 3                   33970             24035.20        93000    RESIDENT
# 4                   36161             31778.00       163000    RESIDENT
# 5                   33604             33604.00       534000    RESIDENT
# 6                   36892             26226.40       418000    STUDSUPP
# 7                   34700             25349.60       128000    RESIDENT
# 8                   35796             31486.00       183000    RESIDENT
# 9                   41640             41640.00       481000    RESIDENT
# 10                  42217             42217.00       607000    RESIDENT
# 11                  42005             42005.00      5829843    RESIDENT
# 12                  29952             29952.00      5316000    ATHASSOC
# 13                  35065             35065.00      7000000    ATHASSOC
# 14                  31048             31048.00       120000    STUDSUPP
# 15                  34335             34335.00       333000     ACADI&R
# 16                  34335             34335.00         3000     ACADI&R
# 17                   9863              9863.00        10000    CAMPSUPP
# 18                   8402              8402.00       367000     ACADI&R
# 19                  41974             41974.00        69000    ACADSUPP
# 20                  26665             26665.00      3075000    CAMPSUPP
# 21                  33239             33239.00        75000    CAMPSUPP
# 22                  33239             33239.00       116000    CAMPSUPP
# 23                  33239             33239.00       116000    CAMPSUPP
# 24                  31048             31048.00       179000    ACADSUPP
# 25                  33604             33604.00      6000000    STUDSUPP
# 26                  43466             43466.00       548000    ATHASSOC
# 27                   8767              8767.00       800000    CAMPSUPP
# 28                   8767              8767.00       300000    ATHASSOC
# 29                  40544             40544.00       100000    ATHASSOC
# ..                    ...                  ...          ...         ...
# 144                 36892             36892.00     51900000     ACADI&R
# 145                 36892             36892.00     13700000    CAMPSUPP
# 146                 36892             36892.00     76000000     ACADI&R
# 155               7   10400.0          120  100    0      0
# 156               7   14545.0          120  100    0      0
# 157               7       NaN           45  100    0      0
# 158               7  523761.0          160    1   99      0
# 159               7  122145.0          250  100    0      0
# 160               7    4599.0          220    0    0    100
# 161               7   14061.0          140  100    0      0
# 162               7   22926.0          250   50    0     50
# 163               7   79149.0          140    0    0    100
# 164               7     216.0          140    0    0    100
# 165               7   44076.0          140    0    0    100
# 166               7   34902.0          160   50   50      0
# 167               7    2054.0          110  100    0      0
# 168               2    3800.0           50    0  100      0
# 169               4    2907.0          140  100    0      0
# 170               7   24719.0          250  100    0      0
# 171               4    9239.0          120    0    0    100
# 172               7   89166.0          180   66   22     12
# 173               7   16713.0          140  100    0      0
#
# [174 rows x 16 columns]

# %%
# Adds Energy Column ands the appropriate total. Removes rows that do not have an energy total
df_corr = add_energy_cons_col(df_corr)

# Drop Rows that have total Energy Consumption Equal to 0 and Remove Columns
df_corr = df_corr[df_corr['Energy Cons'] != 0]
df_corr = df_corr.drop(['Facility'], axis = 1)
# Out:
# C:\Users\Kunal\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of Matched and Updated Buildings: 108

# %%
# Orignial Correlation Dataframe Columns
print(df_corr.columns.values)
df_corr
# Out:
# ['Area' 'Ownership' 'Primary Use' 'Condition' 'Constr Date Num'
#  'Constr Date Replaced' 'Constr Replaced pct' 'Constr Cost' 'GT Category'
#  'FIR Constr Type' 'ASF' 'Avg cost/sf' 'RI' 'Aux' 'Other' 'Energy Cons']
#        Area Ownership Primary Use Condition  Constr Date Num  \
# 0    139914         1           2  REM26-50            21551
# 1     25645         1           1     SATIS             4019
# 2     63848         1          23     SATIS            17168
# 3     17423         1          22     SATIS             9133
# 4     23933         1          22     SATIS            14246
# 5     25558         1          22     SATIS             9498
# 6     19986         1           8     SATIS            10228
# 7     23117         1          22     SATIS            11324
# 8     30526         1          22     SATIS            14246
# 9     59986         1          23     SATIS            17168
# 12    72775         2           1     SATIS            29952
# 14      384         1           1     SATIS            31048
# 15    22294         1           4     SATIS            15342
# 18    38306         1           2  REM26-50             8402
# 19    10310         1           1     SATIS             3654
# 20    34372         1           6    REM>51             5115
# 24    33107         1           1     SATIS                1
# 25    48666         1           1     SATIS            33604
# 26     7591         1           1     SATIS            32143
# 27   111907         1           1    REM<26             8767
# 29     6478         1           1     SATIS             8767
# 31    48713         1           1     SATIS                1
# 32    10231         1           1     SATIS             2193
# 33    25855         1           1    REM<26              367
# 34    31154         1           2     SATIS                1
# 35    24442         1           4     SATIS            10959
# 36    37818         1           4    REM>51            13881
# 37    77867         1           4     SATIS             7306
# 38    10472         1           1     SATIS            29587
# 39   120422         1           1     SATIS            31778
# ..      ...       ...         ...       ...              ...
# 109  289933         1          23     SATIS            34700
# 110  132885         1          23     SATIS            34700
# 111  152789         1          23     SATIS            34700
# 115  121973         1           4     SATIS            34700
# 116   30274         1           4     SATIS            25569
# 118   44856         1           1     SATIS            30682
# 121  158124         1           4     SATIS            36526
# 122   33030         1           4     SATIS            35796
# 123  155241         8           4     SATIS            36161
# 124  292144         1           4     SATIS            37257
# 125   31994         1           4     SATIS            35796
# 126   21491         1           4     SATIS            36526
# 127    6401         1           4     SATIS            36526
# 128  319022         9           4     SATIS            38718
# 129   12345         1           1     SATIS            31413
# 132   20357         1           2     SATIS            32143
# 133   72041         2           9     SATIS            36892
# 137   99822         1           3     SATIS            37257
# 139  292838         2           3     SATIS            38950
# 142  143669         2           2     SATIS            36892
# 145   67423         2           1     SATIS            36892
# 148   38750         1           5     SATIS            37257
# 151  394386         2          24     SATIS            37987
# 152  194852         9           4     SATIS            39448
# 153   23300         1           4     SATIS            31778
# 157     624         2          16     SATIS            38718
# 160    7094         1          10     SATIS            39448
# 162   46888         2           4     SATIS            40909
# 163   82144         1           9     SATIS            40544
# 165   50935         1           9     SATIS            41275
#
#      Constr Date Replaced  Constr Replaced pct  Constr Cost GT Category  \
# 0                   34700             27205.07      2037000     ACADI&R
# 1                   28856             28856.00      1142000    CAMPSUPP
# 2                   33970             27249.20       614000    RESIDENT
# 3                   33970             24035.20        93000    RESIDENT
# 4                   36161             31778.00       163000    RESIDENT
# 5                   33604             33604.00       534000    RESIDENT
# 6                   36892             26226.40       418000    STUDSUPP
# 7                   34700             25349.60       128000    RESIDENT
# 8                   35796             31486.00       183000    RESIDENT
# 9                   41640             41640.00       481000    RESIDENT
# 12                  29952             29952.00      5316000    ATHASSOC
# 14                  31048             31048.00       120000    STUDSUPP
# 15                  34335             34335.00       333000     ACADI&R
# 18                   8402              8402.00       367000     ACADI&R
# 19                  41974             41974.00        69000    ACADSUPP
# 20                  26665             26665.00      3075000    CAMPSUPP
# 24                  31048             31048.00       179000    ACADSUPP
# 25                  33604             33604.00      6000000    STUDSUPP
# 26                  43466             43466.00       548000    ATHASSOC
# 27                   8767              8767.00       800000    CAMPSUPP
# 29                  40544             40544.00       100000    ATHASSOC
# 31                  42736             42736.00        43250    ACADSUPP
# 32                  39083             18793.50       170000    ACADSUPP
# 33                  31778             23925.25       154000    ACADSUPP
# 34                  38565             38565.00       142000     ACADI&R
# 35                  34700             34700.00       162000     ACADI&R
# 36                  13881             13881.00       314000     ACADI&R
# 37                  37622             37622.00       491000     ACADI&R
# 38                  39814             34700.50       615000    CAMPSUPP
# 39                  31778             31778.00      9500000    CAMPSUPP
# ..                    ...                  ...          ...         ...
# 109                 34700             34700.00     24844000    RESIDENT
# 110                 34700             34700.00     13235000    RESIDENT
# 111                 36161             35065.25     14024000    RESIDENT
# 115                 34700             34700.00     16305000     ACADI&R
# 116                 25569             25569.00       520000     ACADI&R
# 118                 30682             30682.00       200000    CAMPSUPP
# 121                 36526             36526.00     27260000     ACADI&R
# 122                 35796             35796.00      3574000     ACADI&R
# 123                 36161             36161.00     31770000     ACADI&R
# 124                 37257             37257.00     58216000     ACADI&R
# 125                 35796             35796.00      6925000     ACADI&R
# 126                 36526             36526.00      6556000     ACADI&R
# 132               7   17725.0          190  100    0      0       167914
# 133               7   47784.0          170  100    0      0      7787974
# 137               7   62888.0          220  100    0      0      2316971
# 139               7  182446.0          220   95    5      0      7339306
# 142               7   76652.0          190   95    5      0      2144206
# 145               7   37448.0          160   75    0     25      4237635
# 148               7   27547.0          250    0  100      0       303310
# 151               7  254375.0          160    1   99      0      2841070
# 152               7  102880.0          250  100    0      0      7687247
# 153               7   16408.0          180   80    0     20       695057
# 157               7       NaN           45  100    0      0     56880000
# 160               7    4599.0          220    0    0    100        68076
# 162               7   22926.0          250   50    0     50       344102
# 163               7   79149.0          140    0    0    100       334440
# 165               7   44076.0          140    0    0    100       297984
#
# [108 rows x 16 columns]

# %%
df_corr_orig = df_corr
df_corr = df_corr.corr()
# Create Correlation Matrix
print(df_corr.columns.values)
df_corr
# Out:
# ['Area' 'Constr Date Num' 'Constr Date Replaced' 'Constr Replaced pct'
#  'Constr Cost' 'ASF' 'Avg cost/sf' 'RI' 'Aux' 'Other' 'Energy Cons']
#                           Area  Constr Date Num  Constr Date Replaced  \
# Area                  1.000000         0.396015              0.045331
# Constr Date Num       0.396015         1.000000              0.224219
# Constr Date Replaced  0.045331         0.224219              1.000000
# Constr Replaced pct   0.098306         0.366552              0.897091
# Constr Cost           0.713322         0.510961              0.202591
# ASF                   0.981279         0.447715              0.046606
# Avg cost/sf           0.161304         0.120196             -0.083318
# RI                   -0.001607        -0.075930             -0.315487
# Aux                   0.069232        -0.016515              0.224008
# Other                -0.114918         0.162856              0.178877
# Energy Cons           0.065590         0.180277              0.039698
#
#                       Constr Replaced pct  Constr Cost       ASF  Avg cost/sf  \
# Area                             0.098306     0.713322  0.981279     0.161304
# Constr Date Num                  0.366552     0.510961  0.447715     0.120196
# Constr Date Replaced             0.897091     0.202591  0.046606    -0.083318
# Constr Replaced pct              1.000000     0.285890  0.104904     0.014871
# Constr Cost                      0.285890     1.000000  0.725515     0.190907
# ASF                              0.104904     0.725515  1.000000     0.175517
# Avg cost/sf                      0.014871     0.190907  0.175517     1.000000
# RI                              -0.200802     0.096029 -0.009132     0.414877
# Aux                              0.073011    -0.067610  0.060625    -0.379840
# Other                            0.232190    -0.055424 -0.086675    -0.090192
# Energy Cons                      0.087004     0.352486  0.387033     0.064385
#
#                             RI       Aux     Other  Energy Cons
# Area                 -0.001607  0.069232 -0.114918     0.065590
# Constr Date Num      -0.075930 -0.016515  0.162856     0.180277
# Constr Date Replaced -0.315487  0.224008  0.178877     0.039698
# Constr Replaced pct  -0.200802  0.073011  0.232190     0.087004
# Constr Cost           0.096029 -0.067610 -0.055424     0.352486
# ASF                  -0.009132  0.060625 -0.086675     0.387033
# Avg cost/sf           0.414877 -0.379840 -0.090192     0.064385
# RI                    1.000000 -0.835288 -0.353926     0.186724
# Aux                  -0.835288  1.000000 -0.218595    -0.154673
# Other                -0.353926 -0.218595  1.000000    -0.068291
# Energy Cons           0.186724 -0.154673 -0.068291     1.000000

# %% [markdown]
# ### Correlation Between Continuous Columns

# %%
# Plot Correlation Heatmap
plot_corr_heatmap(df_corr)

# %%
# Plots a scatter plot of the all of the columns in df_corr in respect to each other
plot_corr_scatter_sns(df_corr, df_corr_orig, 'Energy Cons', hue='GT Category')

# %% [markdown]
# ### Correlation Between Categorical and Continuous Columns

# %% [markdown]
# ####  Condition Analysis

# %%
import warnings
warnings.filterwarnings(action='ignore') # action='once' or 'ignore'

# %%
# Returns an Array with all possible types for a Categorical Variable in a Dataframe
# param df (dataframe) - dataframe to search in
# param cat_col (str) - Dataframe column with the Categories
def get_cat_list(df, col_name):
    return list(df[col_name].value_counts().index)

# Creates an Array for Each Category Type, the Array Contains all Continous elements that have that type
# param df (dataframe) - dataframe to search in
# param cat_col (str) - Dataframe column with the Categories
# param val_col (str) - Dataframe column with the Values
# returns arr_2d (2d Arr)
def cat_cont_analysis(df, cat_col, val_col):
    cat_list = get_cat_list(df, cat_col)
    arr_2d = [[] for i in range(len(cat_list))]
    types = df[cat_col].reset_index().drop(columns=['index'])
    values = df[val_col].reset_index().drop(columns=['index'])
    for i in range(df_corr_orig.shape[0]): arr_2d[cat_list.index(types[cat_col][i])].append(values[val_col][i])
    return arr_2d

# Plots the Category Distributions of an associated continuous value
# param df (dataframe) - dataframe to search in
# param cat_col (str) - Dataframe column with the Categories
# param arr_2d (2d Arr) - Array of Arrays with Values for Each Category Type
def plot_cat_dist(df, cat_col, arr_2d):
    cat_list = get_cat_list(df_corr_orig, cat_col)
    for i in range(len(arr_2d)):
        sns.distplot(arr_2d[i]).set_title(cat_list[i])
        plt.show()

# Plots the Category Distributions of an associated continuous value
# param df (dataframe) - dataframe to search in
# param cat_col (str) - Dataframe column with the Categories
# param val_col (str) - Dataframe column with the Values
def cat_dist(df, cat_col, val_col):
    arr_2d = cat_cont_analysis(df, cat_col, val_col)
    plot_cat_dist(df, cat_col, arr_2d)

# Plots the Frequency Distribution of a Categorical Column in a Dataframe
# param df (dataframe) - dataframe to search in
# param cat_col (str) - Dataframe column with the Categories
def freq_dist(df, cat_col):
    cond_count = df[cat_col].value_counts()
    sns.set(style="darkgrid")
    sns.barplot(cond_count.index, cond_count.values, alpha=0.9)
    plt.title(cat_col +' Distribution')
    plt.ylabel('Number of Occurrences', fontsize=12)
    plt.xlabel(cat_col, fontsize=12)
    plt.show()

# %%
freq_dist(df_corr_orig, 'Condition')

# %%
# Box Plot
# Box Plot
fig, ax = plt.subplots()
df_corr_orig.boxplot('Energy Cons','Condition', vert=False, ax=ax, sym='')
plt.show()

# %%
cat_dist(df_corr_orig, 'Condition', 'Energy Cons')

# %% [markdown]
# #### GT Category Analysis

# %%
freq_dist(df_corr_orig, 'GT Category')

# %%
# Box Plot
fig, ax = plt.subplots()
df_corr_orig.boxplot('Energy Cons','GT Category', vert=False, ax=ax, sym='')
ax.margins(y=500000)
plt.show()

# %%
cat_dist(df_corr_orig, 'GT Category', 'Energy Cons')
